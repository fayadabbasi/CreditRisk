# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.set_option('max_colwidth', 5000)
import pandas_profiling
from IPython.display import display
from feature_engine.categorical_encoders import OneHotCategoricalEncoder

# %% [markdown]
# ## Read In CSV Files
# Remember that I now have 4 files, the train test split with and without targets

# %%
loan_data_inputs_train = pd.read_csv('/Users/fayadabbasi/Desktop/Python_Scripts/Galvanize/DSI/CreditRisk/loan_data_inputs_train.csv', index_col=0)
# Out:
# /Users/fayadabbasi/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
loan_data_targets_train = pd.read_csv('/Users/fayadabbasi/Desktop/Python_Scripts/Galvanize/DSI/CreditRisk/loan_data_target_train.csv',index_col=0, header=None)
# Out:
# /Users/fayadabbasi/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
loan_data_inputs_train.head(1)
# Out:
#                 id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 2320939  151533837     6000.0       6000.0           6000.0   36 months
#
#         int_rate  installment grade sub_grade       emp_title emp_length  \
# 2320939    8.81%       190.27     A        A5  Plant Engineer     1 year
#
#         home_ownership  annual_inc verification_status   issue_d loan_status  \
# 2320939           RENT     76400.0        Not Verified  May-2019     Current
#
#         pymnt_plan purpose  title zip_code addr_state    dti  delinq_2yrs  \
# 2320939          n   other  Other    145xx         NY  14.77          0.0
#
#         earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 2320939         Mar-2005             0.0                     NaN
#
#          mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  \
# 2320939                     NaN      11.0      0.0     3367.0       6.7%
#
#          total_acc initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 2320939       16.0                   w    5558.11        5558.11       567.87
#
#          total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 2320939           567.87           441.89         125.98                 0.0
#
#          recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 2320939         0.0                      0.0     Aug-2019           190.27
#
#         next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 2320939     Sep-2019           Aug-2019                         0.0
#
#          mths_since_last_major_derog  policy_code application_type  \
# 2320939                          NaN          1.0       Individual
#
#          annual_inc_joint  dti_joint verification_status_joint  \
# 2320939               NaN        NaN                       NaN
#
#          acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 2320939             0.0           0.0      23812.0          0.0          3.0
#
#          open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 2320939          1.0          3.0                 8.0       20445.0     69.0
#
#          open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 2320939          3.0          5.0      3367.0      30.0           50300.0
#
#          inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 2320939     1.0          0.0           3.0                   8.0       2165.0
#
#          bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 2320939         40733.0      7.6                       0.0          0.0
#
#          mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 2320939               170.0                  57.0                    7.0
#
#          mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 2320939             7.0       0.0                   7.0
#
#          mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 2320939                       NaN                    7.0
#
#          mths_since_recent_revol_delinq  num_accts_ever_120_pd  \
# 2320939                             NaN                    0.0
#
#          num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  \
# 2320939             1.0              1.0          7.0        9.0        5.0
#
#          num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  num_sats  \
# 2320939            8.0           11.0                  1.0      11.0
#
#          num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 2320939               0.0           0.0                 0.0
#
#          num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 2320939                 4.0           100.0               0.0
#
#          pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# 2320939                   0.0        0.0          79783.0            23812.0
#
#          total_bc_limit  total_il_high_credit_limit  revol_bal_joint  \
# 2320939         44100.0                     29483.0              NaN
#
#         sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 2320939                      NaN                     NaN               NaN
#
#          sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 2320939               NaN                 NaN                  NaN
#
#          sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 2320939                    NaN                               NaN
#
#          sec_app_collections_12_mths_ex_med  \
# 2320939                                 NaN
#
#          sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 2320939                                  NaN             N           NaN
#
#         hardship_reason hardship_status  deferral_term  hardship_amount  \
# 2320939             NaN             NaN            NaN              NaN
#
#         hardship_start_date hardship_end_date payment_plan_start_date  \
# 2320939                 NaN               NaN                     NaN
#
#          hardship_length  hardship_dpd hardship_loan_status  \
# 2320939              NaN           NaN                  NaN
#
#          hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 2320939                             NaN                           NaN
#
#         debt_settlement_flag debt_settlement_flag_date settlement_status  \
# 2320939                    N                       NaN               NaN
#
#         settlement_date  settlement_amount  settlement_percentage  \
# 2320939             NaN                NaN                    NaN
#
#          settlement_term  emp_length_int  term_int earliest_cr_line_date  \
# 2320939              NaN             1.0        36            2005-03-01
#
#          mths_since_earliest_cr_line issue_d_date  mths_since_issue_d  \
# 2320939                        173.0   2019-05-01                 3.0
#
#          grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 2320939        1        0        0        0        0        0        0
#
#          sub_grade:A1  sub_grade:A2  sub_grade:A3  sub_grade:A4  sub_grade:A5  \
# 2320939             0             0             0             0             1
#
#          sub_grade:B1  sub_grade:B2  sub_grade:B3  sub_grade:B4  sub_grade:B5  \
# 2320939             0             0             0             0             0
#
#          sub_grade:C1  sub_grade:C2  sub_grade:C3  sub_grade:C4  sub_grade:C5  \
# 2320939             0             0             0             0             0
#
#          sub_grade:D1  sub_grade:D2  sub_grade:D3  sub_grade:D4  sub_grade:D5  \
# 2320939             0             0             0             0             0
#
#          sub_grade:E1  sub_grade:E2  sub_grade:E3  sub_grade:E4  sub_grade:E5  \
# 2320939             0             0             0             0             0
#
#          sub_grade:F1  sub_grade:F2  sub_grade:F3  sub_grade:F4  sub_grade:F5  \
# 2320939             0             0             0             0             0
#
#          sub_grade:G1  sub_grade:G2  sub_grade:G3  sub_grade:G4  sub_grade:G5  \
# 2320939             0             0             0             0             0
#
#          home_ownership:ANY  home_ownership:MORTGAGE  home_ownership:NONE  \
# 2320939                   0                        0                    0
#
#          home_ownership:OTHER  home_ownership:OWN  home_ownership:RENT  \
# 2320939                     0                   0                    1
#
#          verification_status:Not Verified  \
# 2320939                                 1
#
#          verification_status:Source Verified  verification_status:Verified  \
# 2320939                                    0                             0
#
#          loan_status:Charged Off  loan_status:Current  loan_status:Default  \
# 2320939                        0                    1                    0
#
#          loan_status:Does not meet the credit policy. Status:Charged Off  \
# 2320939                                                                0
#
#          loan_status:Does not meet the credit policy. Status:Fully Paid  \
# 2320939                                                               0
#
#          loan_status:Fully Paid  loan_status:In Grace Period  \
# 2320939                       0                            0
#
#          loan_status:Late (16-30 days)  loan_status:Late (31-120 days)  \
# 2320939                              0                               0
#
#          purpose:car  purpose:credit_card  purpose:debt_consolidation  \
# 2320939            0                    0                           0
#
#          purpose:educational  purpose:home_improvement  purpose:house  \
# 2320939                    0                         0              0
#
#          purpose:major_purchase  purpose:medical  purpose:moving  \
# 2320939                       0                0               0
#
#          purpose:other  purpose:renewable_energy  purpose:small_business  \
# 2320939              1                         0                       0
#
#          purpose:vacation  purpose:wedding  addr_state:AK  addr_state:AL  \
# 2320939                 0                0              0              0
#
#          addr_state:AR  addr_state:AZ  addr_state:CA  addr_state:CO  \
# 2320939              0              0              0              0
#
#          addr_state:CT  addr_state:DC  addr_state:DE  addr_state:FL  \
# 2320939              0              0              0              0
#
#          addr_state:GA  addr_state:HI  addr_state:IA  addr_state:ID  \
# 2320939              0              0              0              0
#
#          addr_state:IL  addr_state:IN  addr_state:KS  addr_state:KY  \
# 2320939              0              0              0              0
#
#          addr_state:LA  addr_state:MA  addr_state:MD  addr_state:ME  \
# 2320939              0              0              0              0
#
#          addr_state:MI  addr_state:MN  addr_state:MO  addr_state:MS  \
# 2320939              0              0              0              0
#
#          addr_state:MT  addr_state:NC  addr_state:ND  addr_state:NE  \
# 2320939              0              0              0              0
#
#          addr_state:NH  addr_state:NJ  addr_state:NM  addr_state:NV  \
# 2320939              0              0              0              0
#
#          addr_state:NY  addr_state:OH  addr_state:OK  addr_state:OR  \
# 2320939              1              0              0              0
#
#          addr_state:PA  addr_state:RI  addr_state:SC  addr_state:SD  \
# 2320939              0              0              0              0
#
#          addr_state:TN  addr_state:TX  addr_state:UT  addr_state:VA  \
# 2320939              0              0              0              0
#
#          addr_state:VT  addr_state:WA  addr_state:WI  addr_state:WV  \
# 2320939              0              0              0              0
#
#          addr_state:WY  initial_list_status:f  initial_list_status:w  \
# 2320939              0                      0                      1
#
#          home_ownership:NONE_RENT_OWN_MORTGAGE  addr_state:OK_AR_LA_MS  \
# 2320939                                      1                       0
#
#          addr_state:NV_NY  addr_state:HI_FL_NM  \
# 2320939                 1                    0
#
#          addr_state:MD_MO_AK_PA_NC_NJ_IN  addr_state:KY_CA  \
# 2320939                                0                 0
#
#          addr_state:SD_NE_TN_MI_DE_VA  addr_state:MN_AZ_TX_OH  \
# 2320939                             0                       0
#
#          addr_state:UT_GA_WI  addr_state:IL_CT_RI_MT  addr_state:WY_KS_WA  \
# 2320939                    0                       0                    0
#
#          addr_state:ND_CO  addr_state:SC_OR_DC  term:36  term:60  \
# 2320939                 0                    0        1        0
#
#          emp_length:0  emp_length:1  emp_length:2-6  emp_length:7  \
# 2320939             0             1               0             0
#
#          emp_length:8  emp_length:9  emp_length:10 mths_since_issue_d_factor  \
# 2320939             0             0              0              (1.856, 5.6]
#
#          purpose:MOV_REN  purpose:WED_DEBTCON_MEDICAL  purpose:OTH_HOUSE  \
# 2320939                0                            0                  1
#
#          purpose:MAJPUR_VAC_HI  purpose:CC_CAR int_rate_factor_test  \
# 2320939                      0               0       (8.392, 8.905]
#
#         int_rate_factor
# 2320939  (8.392, 8.905]

# %%
print("inputs train shape: {} \ntargets train shape: {}".format(loan_data_inputs_train.shape, loan_data_targets_train.shape))
# Out:
# inputs train shape: (1788564, 303)
# targets train shape: (1788564, 1)

# %% [markdown]
# ## Create working file
# This will include only those modified columns from my preprocessing
# <br/>
# as well as my one_hot_encoding

# %%
inputs_train_w_ref_cat = loan_data_inputs_train.loc[:,[#list]]
